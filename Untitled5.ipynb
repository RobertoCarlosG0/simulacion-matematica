# %%
import numpy as np

np.random.normal
# Out:
# <function RandomState.normal>

# %%
hombres = np.random.normal(82, 5, (10,100000))

import pandas as pd
tabla = pd.DataFrame(hombres)
tabla
# Out:
#        0          1          2          3          4          5      \
# 0  82.115301  88.402882  79.749154  85.932974  78.913696  84.647626
# 1  78.143036  84.756122  78.016661  86.207128  77.313670  75.955762
# 2  85.060924  73.871931  84.736587  80.382884  79.806222  82.500886
# 3  90.111272  79.344299  76.603305  80.182409  76.261053  81.859119
# 4  82.730249  80.951316  85.183800  76.563169  83.752639  88.380628
# 5  82.572784  80.361018  78.062937  80.091338  75.103424  85.248791
# 6  82.132794  87.876623  79.262732  75.189580  83.507055  72.320596
# 7  88.687602  84.645280  88.999462  83.937426  82.513858  83.240018
# 8  81.508116  79.087784  84.313352  75.501360  78.532740  84.021707
# 9  73.730373  71.917244  81.126177  70.122378  83.308503  85.730830
#
#        6          7          8          9      ...      99990      99991  \
# 0  91.999952  85.154856  78.822188  81.097993  ...  84.042759  66.666718
# ...

# %%
(tabla.sum() <= 800).mean()
# Out:
# 0.10322

# %%
import numpy as np

np.random.uniform
# Out:
# <function RandomState.normal>

# %%
vigas = np.random.uniform(.9, 1.07, (3,100000))

import pandas as pd
tabla = pd.DataFrame(vigas)
tabla
# Out:
#       0         1         2         3         4         5         6      \
# 0  0.952023  0.958868  0.900166  0.921267  0.918231  1.001294  1.036245
# 1  0.912779  1.020262  0.998987  0.946477  1.014685  0.990035  0.913324
# 2  1.012246  1.017084  0.922053  0.955302  0.963544  1.052949  1.048811
#
#       7         8         9      ...     99990     99991     99992     99993  \
# 0  1.055350  0.914279  0.915766  ...  0.996225  0.969550  1.028289  0.992520
# 1  0.990544  1.057988  0.926665  ...  0.911049  1.023582  0.962004  0.996377
# 2  0.958283  0.955744  0.917606  ...  1.049226  0.946371  0.925294  0.927553
#
#       99994     99995     99996     99997     99998     99999
# 0  1.012315  0.937822  1.008002  1.008161  0.915840  1.013056
# 1  1.037385  1.039424  0.911740  0.968194  1.039622  1.039797
# 2  0.924357  1.065811  0.916207  0.934371  1.046385  0.988652
#
# [3 rows x 100000 columns]

# %%
(tabla.sum() > 3 ).mean()
# Out:
# 0.30974

# %%
import numpy as np

np.random.normal
# Out:
# <function RandomState.uniform>

# %%
avion = np.random.normal(6, 1, (1,100000))

import pandas as pd
tabla = pd.DataFrame(avion)
tabla
# Out:
#       0         1         2        3         4         5         6      \
# 0  5.198787  4.731465  5.841564  5.52823  6.609593  5.269974  4.946422
#
#      7         8         9      ...     99990     99991     99992     99993  \
# 0  5.16703  5.680495  6.291694  ...  5.375933  6.906784  6.967731  3.738112
#
#       99994     99995    99996     99997    99998     99999
# 0  5.546395  6.450374  6.42403  6.068704  7.31767  5.481523
#
# [1 rows x 100000 columns]

# %%
tabla.sum().mean()
# Out:
# 5.99547922710395

# %%
import numpy as np

np.random.uniform
# Out:
# <function RandomState.uniform>

# %%
avion = np.random.uniform(7, 21, (1,100000))

import pandas as pd
tabla1 = pd.DataFrame(avion)
tabla1
# Out:
#        0          1         2         3          4          5          6      \
# 0  13.708904  20.493383  9.933829  20.88491  13.486005  10.182417  19.513693
#
#      7          8          9      ...      99990      99991      99992  \
# 0  8.29922  11.469507  15.014146  ...  19.326319  14.318962  12.358378
#
#        99993      99994      99995      99996     99997      99998      99999
# 0  14.064867  17.569022  15.068628  12.216795  9.783712  18.170973  11.091112
#
# [1 rows x 100000 columns]

# %%
tabla1.sum().mean()
# Out:
# 13.992799176787091

# %%
(tabla1.sum().mean()) + (tabla.sum().mean())
# Out:
# 21.06121773913558
